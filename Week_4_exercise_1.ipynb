# %% [markdown]
# <a href="https://colab.research.google.com/github/MargauxCNH/2024_Intro_Python/blob/main/Week_4_exercise_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # (Exercises) Multivariate linear regression and clustering
#
# What if our dataset has multiple dimensions and we want to find equations that looks something like this?
# $$
# y = w_1 x_1 + w_2 x_2 + w_3 x_3 + ... + b
# $$
#
# Here we show how we would do it with scikit-learn to find a linear equation that describes the Kaggle [Advertising dataset](https://www.kaggle.com/datasets/bumba5341/advertisingcsv?resource=download)

# %% [markdown]
# ## Exercise 1: Multivariate linear regression

# %% [markdown]
# ### Q1: Use pandas to import the advertising dataset

# %%
import numpy as np
import matplotlib.pyplot as plt
import pooch
import urllib.request
import pandas as pd

# %%
myadvertising = pooch.retrieve('https://unils-my.sharepoint.com/:x:/g/personal/tom_beucler_unil_ch/EeqnI6nF9iBAkUOACbZ3mWUBDZ8N5mVP1oOaFd4vy6tIzw?download=1',
                          known_hash='69104adc017e75d7019f61fe66ca2eb4ab014ee6f2a9b39b452943f209352010')
# Out:
# Downloading data from 'https://unils-my.sharepoint.com/:x:/g/personal/tom_beucler_unil_ch/EeqnI6nF9iBAkUOACbZ3mWUBDZ8N5mVP1oOaFd4vy6tIzw?download=1' to file '/root/.cache/pooch/271dfe3e2b688abba76aa7d860de6650-EeqnI6nF9iBAkUOACbZ3mWUBDZ8N5mVP1oOaFd4vy6tIzw'.

# %%
# Q1a: Use pandas to import the dataset

# %%
# Q1b: Display the first rows of the data with pandas

# %%
myadvertising = pd.read_csv(myadvertising)

# %%
myadvertising.head()
# Out:
#    Unnamed: 0     TV  Radio  Newspaper  Sales
# 0           1  230.1   37.8       69.2   22.1
# 1           2   44.5   39.3       45.1   10.4
# 2           3   17.2   45.9       69.3    9.3
# 3           4  151.5   41.3       58.5   18.5
# 4           5  180.8   10.8       58.4   12.9

# %%
#@title Code skeleton
# Q1a: Use pandas to import the dataset
__ = pd.__(_,_)
# Q1b: Display the first rows of the data with pandas
__.__()

# %% [markdown]
# ### Q2: Try to use scikit-learn linear regression model to predict "Sales" from three columns "TV", "Radio", "Newspaper"
#
# This model will basically tell us how sales would change if we put resources to advertise products in three different medias. The [Linear Regression documentation is at this link](https://scikit-learn.org/1.5/modules/generated/sklearn.linear_model.LinearRegression.html).

# %%
# Import the linear regression model you wish to use

# %%
from sklearn.linear_model import LinearRegression

# %%
# Construct Input / Output matrices
# and instantiate / train a linear regression model

# %%
Xall = myadvertising[["TV","Radio","Newspaper"]].values
y = myadvertising['Sales'].values
linreg = LinearRegression()
linreg.fit(Xall,y)
# Out:
# LinearRegression()

# %%
#@title Code skeleton
from sklearn.____ import ____

# Construct Input / Output matrices
Xall = __[[_,_,_]].values
y = _[].values
linreg = ___
linreg.__(_,_)

# %% [markdown]
# ### Q3: Print out the linear equation coefficients and intercept
#
# Hints:
#
# (1) When you print the coefficients and intercepts, try to retain only the first two digits. One way to do it is through the `.round()` function in `numpy`
#
# (2) Check out the scikit-learn `linear-model` module for instructions on extracting the coefficients and intercepts of the trained model.

# %%
# Print your coefficients and intercept here.
print(f'Coefficients {}, Intercept {}' )
# Out:
#   File "<ipython-input-7-b156fdeb6110>", line 2
#     print(f'Coefficients {}, Intercept {}' )
#                                            ^
# SyntaxError: f-string: empty expression not allowed

# %%
print(f'Coefficients {linreg.coef_.round(2)}, Intercept {linreg.intercept_}')
# Out:
# Coefficients [ 0.05  0.19 -0.  ], Intercept 2.938889369459412

# %% [markdown]
# ## Exercise 2: Clustering Penguin Dataset
#
# In the exercise, we will try to repeat the k-mean clustering procedure introuduced in the tutorial, but on a different 2D variable plane.
#
# Let's try "culmen_length_mm" and "Flipper_length_mm"?
#
# Can we differentiate penguins from the length of the beak and their wings?
#
# <img style="padding: 10px; float:left;" alt="20 points and their Voronoi cells by Balu Ertl CC BY-SA 4.0" src="https://allisonhorst.github.io/palmerpenguins/reference/figures/culmen_depth.png" width="400">

# %%
penguinsize = pooch.retrieve('https://unils-my.sharepoint.com/:x:/g/personal/tom_beucler_unil_ch/ETfy8shC_PtBnsYren_f60UBSyn6Zz1CVvE0Z6_z575VZA?download=1',
                          known_hash='aa728597b2228a2637e39c6f08e40a80971f4cdac7faf7bc21ff4481ee3e3ae9')

penguins = pd.read_csv(penguinsize)
print(penguins.head())
# Out:
# Downloading data from 'https://unils-my.sharepoint.com/:x:/g/personal/tom_beucler_unil_ch/ETfy8shC_PtBnsYren_f60UBSyn6Zz1CVvE0Z6_z575VZA?download=1' to file '/root/.cache/pooch/15990ae8be04e5655e98ecb908600619-ETfy8shC_PtBnsYren_f60UBSyn6Zz1CVvE0Z6_z575VZA'.
#   species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen              39.1             18.7              181.0
# 1  Adelie  Torgersen              39.5             17.4              186.0
# 2  Adelie  Torgersen              40.3             18.0              195.0
# 3  Adelie  Torgersen               NaN              NaN                NaN
# 4  Adelie  Torgersen              36.7             19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    MALE
# 1       3800.0  FEMALE
# 2       3250.0  FEMALE
# 3          NaN     NaN
# 4       3450.0  FEMALE

# %% [markdown]
# ### Q1: Data clean up. Remove all rows in the table if the rows contain missing values
#
# Hint: `pandas` has a easy function for data clean up. Check out [documentation](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.dropna.html) for details.

# %%
# Clean up the data here
penguin_df = penguins.resample

# %%
penguin_df = penguins.dropna()

# %%
#@title Code skeleton
penguin_df = penguins.___________

# %% [markdown]
# ### Q2: Create an input dataset `X` with the culmen_length_mm and flipper_length_mm data columns
#
# Hints:
#
# (1) The shape of your input data should be `(334, 2)`

# %%
penguin_df
# Out:
#     species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen              39.1             18.7              181.0
# 1    Adelie  Torgersen              39.5             17.4              186.0
# 2    Adelie  Torgersen              40.3             18.0              195.0
# 4    Adelie  Torgersen              36.7             19.3              193.0
# 5    Adelie  Torgersen              39.3             20.6              190.0
# ..      ...        ...               ...              ...                ...
# 338  Gentoo     Biscoe              47.2             13.7              214.0
# 340  Gentoo     Biscoe              46.8             14.3              215.0
# 341  Gentoo     Biscoe              50.4             15.7              222.0
# 342  Gentoo     Biscoe              45.2             14.8              212.0
# 343  Gentoo     Biscoe              49.9             16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    MALE
# 1         3800.0  FEMALE
# 2         3250.0  FEMALE
# 4         3450.0  FEMALE
# 5         3650.0    MALE
# ..           ...     ...
# 338       4925.0  FEMALE
# 340       4850.0  FEMALE
# 341       5750.0    MALE
# 342       5200.0  FEMALE
# 343       5400.0    MALE
#
# [334 rows x 7 columns]

# %%
X = penguin_df[["culmen_length_mm","flipper_length_mm"]].values
print(X.shape)
# Out:
# (334, 2)

# %%
# Create your input for model training here
# Input should contain penguin_df['culmen_length_mm'] and penguin_df['flipper_length_mm']
X = _____________________________________________

# %% [markdown]
# ### Q3: Train a K-means clustering algorithm, and perform an elbow test followed by silhouette analysis
#
# Hints:
#
# (1) The documentation for KMeans clustering can be found [here](https://scikit-learn.org/stable/modules/generated/sklearn.cluster.KMeans.html?highlight=kmeans#sklearn.cluster.KMeans)
#
# (2) [Documentation](https://scikit-learn.org/stable/modules/generated/sklearn.metrics.silhouette_score.html?highlight=silhouette+score#sklearn.metrics.silhouette_score) for silhouette score analysis in scikit-learn

# %%
# Import the KMeans class and
# the Silhouette score function from scikit-learn

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

# %%
#@title Skeleton code
# Import KMeans fron scikit-learn
from sklearn.________ import ______
# Import Silhouette score fron scikit-learn
from sklearn._______ import ________________

# %%
# Store the K-means inertia in an empty list

# %%
inertias = []
for k in range(1, 11):
    kmeans = KMeans(n_clusters=k, random_state=42)
    kmeans.fit(X)
    inertias.append(kmeans.inertia_)

# %%
#@title Skeleton code
# Store the K-means inertia in an empty list
_______________________ = []
_ = ___________
for ___________ in ______ :
 ________ = _______(n_clusters=____________)
 _______.___(X)
 ________________._______(___________)

# %%
# To finish the elbow method analysis,
# plot the change in inertia when you change the number of clusters
# you used to train the k-means clustering algorithm.

# %%
plt.plot(range(1, 11), inertias, marker='s', c='k', lw=2)
plt.xlabel('Number of Clusters')
plt.ylabel('Sum of Squared Distances / Inertia')
plt.title('Elbow Method for Optimal K')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#@title Skeleton code
# To finish the elbow method analysis, plot the change in inertia when you change the number of clusters you used to train the k-means clustering algorithm.
plt.plot(____,__________,marker='s',c='k',lw=2)
plt.xlabel('Number of Clusters')
plt.ylabel('Sum of Squared Distances / Inertia')
plt.title('Elbow Method for Optimal K')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-b3d9993e4bb0> in <cell line: 3>()
#       1 #@title Skeleton code
#       2 # To finish the elbow method analysis, plot the change in inertia when you change the number of clusters you used to train the k-means clustering algorithm.
# ----> 3 plt.plot(____,__________,marker='s',c='k',lw=2)
#       4 plt.xlabel('Number of Clusters')
#       5 plt.ylabel('Sum of Squared Distances / Inertia')
#
# NameError: name '____' is not defined

# %% [markdown]
# This is what your TA got after filling in and running the skeleton code.

# %% [markdown]
# ![plot1.png](data:image/png;base64,...)

# %%
# Perform silhouette analysis following instructions in the tutorial notebook

# %%
from sklearn.metrics import silhouette_score
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

silhouette_avg = []
for num_clusters in range(2,10):
  # initialise kmeans
  kmeans = KMeans(n_clusters=num_clusters)
  kmeans.fit(X)
  cluster_labels = kmeans.labels_
  #silhouette score
  silhouette_avg.append(silhouette_score(X, cluster_labels))

plt.plot(range(2,10), silhouette_avg)
plt.xlabel("Number of clusters")
plt.ylabel("Silhouette score")
plt.show()

# %%
#@title Skeleton code
______________ = []
for num_clusters in range(2,10):
  # initialise kmeans
  ______ = _______(___________)
  ______.fit(X)
  cluster_labels = _______.__________

  # silhouette score
  _____________.append(silhouette_score(_, ________________))

# %%
# Plot your silhouette analysis result here.

# %% [markdown]
# Here is a screenshot of how the results should look like.

# %% [markdown]
# ![plot2.png](data:image/png;base64,...)

# %% [markdown]
# Based on the silhouette and elbow analysis, it seems the either 2 or 3 clusters is suitable for this penguin dataset.

# %% [markdown]
# ### Q4: Perform KMeans clustering with 3 clusters

# %%
# Train a k-means clustering model with 3 clusters
kmeans = KMeans(n_clusters=3)
kmeans.fit(penguin_df[['culmen_length_mm', 'flipper_length_mm']])
# Out:
# KMeans(n_clusters=3)

# %%
labels = kmeans.labels_

# %%
labels = kmeans.predict(penguin_df[['culmen_length_mm', 'flipper_length_mm']])

# %%
# Use the model to label all data points
# Get the cluster labels for each data point
labels = kmeans.labels_

# Add the cluster labels to the DataFrame
penguin_df['cluster'] = labels
# Out:
# <ipython-input-19-b41240b2f559>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   penguin_df['cluster'] = labels

# %%
#@title Skeleton code
# Train a k-means clustering model
kmeans = _______(n_clusters=3)
kmeans._____(_)

# Use the model to label all data points
_______ = kmeans._______(_)

# %% [markdown]
# Now, our penguin dataset is labelled. So we can compare our clustering results with the truth to see how well our trained model performed.

# %% [markdown]
# First store the predicted labels in the pandas dataframe

# %%
# Store the predicted labels in a new index
penguin_df['cluster'] = labels
# Out:
# <ipython-input-23-0d0eec9bd058>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   penguin_df['cluster'] = labels

# %%
#@title Skeleton code
penguin_df[_______] = _____________
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-47709d342468> in <cell line: 2>()
#       1 #@title Skeleton code
# ----> 2 penguin_df[_______] = _____________
#
# NameError: name '_____________' is not defined

# %% [markdown]
# ```
# # This is formatted as code
# ```
#
# Then extract the culmen_length_mm and flipper_length_mm of the three penguin categories as truth

# %%
# Adelie

# Gentoo

# Chinstrap

# %% [markdown]
# Recreate the figure below
#
# ![plot3.png](data:image/png;base64,...)

# %%
# Script to recreate the figure

# %%
adelie_df = penguin_df[penguin_df['species'] == 'Adelie']
gentoo_df = penguin_df[penguin_df['species'] == 'Gentoo']
chinstrap_df = penguin_df[penguin_df['species'] == 'Chinstrap']

adelie_culmen_length = adelie_df['culmen_length_mm']
adelie_flipper_length = adelie_df['flipper_length_mm']

gentoo_culmen_length = gentoo_df['culmen_length_mm']
gentoo_flipper_length = gentoo_df['flipper_length_mm']

chinstrap_culmen_length = chinstrap_df['culmen_length_mm']
chinstrap_flipper_length = chinstrap_df['flipper_length_mm']

plt.scatter(adelie_culmen_length, adelie_flipper_length, c='blue', label='Adelie')
plt.ylabel('Flipper Length (mm)')
plt.xlabel('Culmen Length (mm)')
# Out:
# Text(0.5, 0, 'Culmen Length (mm)')

# %%
adelie_truth = penguins[penguins['species'] == 'Adelie'][['culmen_length_mm', 'flipper_length_mm']].values
gentoo_truth = penguins[penguins['species'] == 'Gentoo'][['culmen_length_mm', 'flipper_length_mm']].values
chinstrap_truth = penguins[penguins['species'] == 'Chinstrap'][['culmen_length_mm', 'flipper_length_mm']].values

print("Adelie Truth (culmen_length_mm, flipper_length_mm):")
print(adelie_truth)
print("\nGentoo Truth (culmen_length_mm, flipper_length_mm):")
print(gentoo_truth)
print("\nChinstrap Truth (culmen_length_mm, flipper_length_mm):")
print(chinstrap_truth)
# Out:
# Adelie Truth (culmen_length_mm, flipper_length_mm):
# [[ 39.1 181. ]
#  [ 39.5 186. ]
#  [ 40.3 195. ]
#  [  nan   nan]
#  [ 36.7 193. ]
#  [ 39.3 190. ]
#  [ 38.9 181. ]
#  [ 39.2 195. ]
#  [ 34.1 193. ]
#  [ 42.  190. ]
#  [ 37.8 186. ]
#  [ 37.8 180. ]
#  [ 41.1 182. ]
#  [ 38.6 191. ]
#  [ 34.6 198. ]
#  [ 36.6 185. ]
#  [ 38.7 195. ]
#  [ 42.5 197. ]
#  [ 34.4 184. ]
#  [ 46.  194. ]
#  [ 37.8 174. ]
#  [ 37.7 180. ]
#  [ 35.9 189. ]
#  [ 38.2 185. ]
#  [ 38.8 180. ]
#  [ 35.3 187. ]
#  [ 40.6 183. ]
#  [ 40.5 187. ]
#  [ 37.9 172. ]
#  [ 40.5 180. ]
#  [ 39.5 178. ]
#  [ 37.2 178. ]
#  [ 39.5 188. ]
#  [ 40.9 184. ]
#  [ 36.4 195. ]
#  [ 39.2 196. ]
#  [ 38.8 190. ]
#  [ 42.2 180. ]
#  [ 37.6 181. ]
#  [ 39.8 184. ]
#  [ 36.5 182. ]
#  [ 40.8 195. ]
#  [ 36.  186. ]
#  [ 44.1 196. ]
#  [ 37.  185. ]
#  [ 39.6 190. ]
#  [ 41.1 182. ]
#  [ 37.5 179. ]
#  [ 36.  190. ]
#  [ 42.3 191. ]
#  [ 39.6 186. ]
#  [ 40.1 188. ]
#  [ 35.  190. ]
#  [ 42.  200. ]
#  [ 34.5 187. ]
#  [ 41.4 191. ]
#  [ 39.  186. ]
#  [ 40.6 193. ]
#  [ 36.5 181. ]
#  [ 37.6 194. ]
#  [ 35.7 185. ]
#  [ 41.3 195. ]
#  [ 37.6 185. ]
#  [ 41.1 192. ]
#  [ 36.4 184. ]
#  [ 41.6 192. ]
#  [ 35.5 195. ]
#  [ 41.1 188. ]
#  [ 35.9 190. ]
#  [ 41.8 198. ]
#  [ 33.5 190. ]
#  [ 39.7 190. ]
#  [ 39.6 196. ]
#  [ 45.8 197. ]
#  [ 35.5 190. ]
#  [ 42.8 195. ]
#  [ 40.9 191. ]
#  [ 37.2 184. ]
#  [ 36.2 187. ]
#  [ 42.1 195. ]
#  [ 34.6 189. ]
#  [ 42.9 196. ]
#  [ 36.7 187. ]
#  [ 35.1 193. ]
#  [ 37.3 191. ]
#  [ 41.3 194. ]
#  [ 36.3 190. ]
#  [ 36.9 189. ]
#  [ 38.3 189. ]
#  [ 38.9 190. ]
#  [ 35.7 202. ]
#  [ 41.1 205. ]
#  [ 34.  185. ]
#  [ 39.6 186. ]
#  [ 36.2 187. ]
#  [ 40.8 208. ]
#  [ 38.1 190. ]
#  [ 40.3 196. ]
#  [ 33.1 178. ]
#  [ 43.2 192. ]
#  [ 35.  192. ]
#  [ 41.  203. ]
#  [ 37.7 183. ]
#  [ 37.8 190. ]
#  [ 37.9 193. ]
#  [ 39.7 184. ]
#  [ 38.6 199. ]
#  [ 38.2 190. ]
#  [ 38.1 181. ]
#  [ 43.2 197. ]
#  [ 38.1 198. ]
#  [ 45.6 191. ]
#  [ 39.7 193. ]
#  [ 42.2 197. ]
#  [ 39.6 191. ]
#  [ 42.7 196. ]
#  [ 38.6 188. ]
#  [ 37.3 199. ]
#  [ 35.7 189. ]
#  [ 41.1 189. ]
#  [ 36.2 187. ]
#  [ 37.7 198. ]
#  [ 40.2 176. ]
#  [ 41.4 202. ]
#  [ 35.2 186. ]
#  [ 40.6 199. ]
#  [ 38.8 191. ]
#  [ 41.5 195. ]
#  [ 39.  191. ]
#  [ 44.1 210. ]
#  [ 38.5 190. ]
#  [ 43.1 197. ]
#  [ 36.8 193. ]
#  [ 37.5 199. ]
#  [ 38.1 187. ]
#  [ 41.1 190. ]
#  [ 35.6 191. ]
#  [ 40.2 200. ]
#  [ 37.  185. ]
#  [ 39.7 193. ]
#  [ 40.2 193. ]
#  [ 40.6 187. ]
#  [ 32.1 188. ]
#  [ 40.7 190. ]
#  [ 37.3 192. ]
#  [ 39.  185. ]
#  [ 39.2 190. ]
#  [ 36.6 184. ]
#  [ 36.  195. ]
#  [ 37.8 193. ]
#  [ 36.  187. ]
#  [ 41.5 201. ]]
#
# Gentoo Truth (culmen_length_mm, flipper_length_mm):
# [[ 46.1 211. ]
#  [ 50.  230. ]
#  [ 48.7 210. ]
#  [ 50.  218. ]
#  [ 47.6 215. ]
#  [ 46.5 210. ]
#  [ 45.4 211. ]
#  [ 46.7 219. ]
#  [ 43.3 209. ]
#  [ 46.8 215. ]
#  [ 40.9 214. ]
#  [ 49.  216. ]
#  [ 45.5 214. ]
#  [ 48.4 213. ]
#  [ 45.8 210. ]
#  [ 49.3 217. ]
#  [ 42.  210. ]
#  [ 49.2 221. ]
#  [ 46.2 209. ]
#  [ 48.7 222. ]
#  [ 50.2 218. ]
#  [ 45.1 215. ]
#  [ 46.5 213. ]
#  [ 46.3 215. ]
#  [ 42.9 215. ]
#  [ 46.1 215. ]
#  [ 44.5 216. ]
#  [ 47.8 215. ]
#  [ 48.2 210. ]
#  [ 50.  220. ]
#  [ 47.3 222. ]
#  [ 42.8 209. ]
#  [ 45.1 207. ]
#  [ 59.6 230. ]
#  [ 49.1 220. ]
#  [ 48.4 220. ]
#  [ 42.6 213. ]
#  [ 44.4 219. ]
#  [ 44.  208. ]
#  [ 48.7 208. ]
#  [ 42.7 208. ]
#  [ 49.6 225. ]
#  [ 45.3 210. ]
#  [ 49.6 216. ]
#  [ 50.5 222. ]
#  [ 43.6 217. ]
#  [ 45.5 210. ]
#  [ 50.5 225. ]
#  [ 44.9 213. ]
#  [ 45.2 215. ]
#  [ 46.6 210. ]
#  [ 48.5 220. ]
#  [ 45.1 210. ]
#  [ 50.1 225. ]
#  [ 46.5 217. ]
#  [ 45.  220. ]
#  [ 43.8 208. ]
#  [ 45.5 220. ]
#  [ 43.2 208. ]
#  [ 50.4 224. ]
#  [ 45.3 208. ]
#  [ 46.2 221. ]
#  [ 45.7 214. ]
#  [ 54.3 231. ]
#  [ 45.8 219. ]
#  [ 49.8 230. ]
#  [ 46.2 214. ]
#  [ 49.5 229. ]
#  [ 43.5 220. ]
#  [ 50.7 223. ]
#  [ 47.7 216. ]
#  [ 46.4 221. ]
#  [ 48.2 221. ]
#  [ 46.5 217. ]
#  [ 46.4 216. ]
#  [ 48.6 230. ]
#  [ 47.5 209. ]
#  [ 51.1 220. ]
#  [ 45.2 215. ]
#  [ 45.2 223. ]
#  [ 49.1 212. ]
#  [ 52.5 221. ]
#  [ 47.4 212. ]
#  [ 50.  224. ]
#  [ 44.9 212. ]
#  [ 50.8 228. ]
#  [ 43.4 218. ]
#  [ 51.3 218. ]
#  [ 47.5 212. ]
#  [ 52.1 230. ]
#  [ 47.5 218. ]
#  [ 52.2 228. ]
#  [ 45.5 212. ]
#  [ 49.5 224. ]
#  [ 44.5 214. ]
#  [ 50.8 226. ]
#  [ 49.4 216. ]
#  [ 46.9 222. ]
#  [ 48.4 203. ]
#  [ 51.1 225. ]
#  [ 48.5 219. ]
#  [ 55.9 228. ]
#  [ 47.2 215. ]
#  [ 49.1 228. ]
#  [ 47.3 216. ]
#  [ 46.8 215. ]
#  [ 41.7 210. ]
#  [ 53.4 219. ]
#  [ 43.3 208. ]
#  [ 48.1 209. ]
#  [ 50.5 216. ]
#  [ 49.8 229. ]
#  [ 43.5 213. ]
#  [ 51.5 230. ]
#  [ 46.2 217. ]
#  [ 55.1 230. ]
#  [ 44.5 217. ]
#  [ 48.8 222. ]
#  [ 47.2 214. ]
#  [  nan   nan]
#  [ 46.8 215. ]
#  [ 50.4 222. ]
#  [ 45.2 212. ]
#  [ 49.9 213. ]]
#
# Chinstrap Truth (culmen_length_mm, flipper_length_mm):
# [[ 46.5 192. ]
#  [ 50.  196. ]
#  [ 51.3 193. ]
#  [ 45.4 188. ]
#  [ 52.7 197. ]
#  [ 45.2 198. ]
#  [ 46.1 178. ]
#  [ 51.3 197. ]
#  [ 46.  195. ]
#  [ 51.3 198. ]
#  [ 46.6 193. ]
#  [ 51.7 194. ]
#  [ 47.  185. ]
#  [ 52.  201. ]
#  [ 45.9 190. ]
#  [ 50.5 201. ]
#  [ 50.3 197. ]
#  [ 58.  181. ]
#  [ 46.4 190. ]
#  [ 49.2 195. ]
#  [ 42.4 181. ]
#  [ 48.5 191. ]
#  [ 43.2 187. ]
#  [ 50.6 193. ]
#  [ 46.7 195. ]
#  [ 52.  197. ]
#  [ 50.5 200. ]
#  [ 49.5 200. ]
#  [ 46.4 191. ]
#  [ 52.8 205. ]
#  [ 40.9 187. ]
#  [ 54.2 201. ]
#  [ 42.5 187. ]
#  [ 51.  203. ]
#  [ 49.7 195. ]
#  [ 47.5 199. ]
#  [ 47.6 195. ]
#  [ 52.  210. ]
#  [ 46.9 192. ]
#  [ 53.5 205. ]
#  [ 49.  210. ]
#  [ 46.2 187. ]
#  [ 50.9 196. ]
#  [ 45.5 196. ]
#  [ 50.9 196. ]
#  [ 50.8 201. ]
#  [ 50.1 190. ]
#  [ 49.  212. ]
#  [ 51.5 187. ]
#  [ 49.8 198. ]
#  [ 48.1 199. ]
#  [ 51.4 201. ]
#  [ 45.7 193. ]
#  [ 50.7 203. ]
#  [ 42.5 187. ]
#  [ 52.2 197. ]
#  [ 45.2 191. ]
#  [ 49.3 203. ]
#  [ 50.2 202. ]
#  [ 45.6 194. ]
#  [ 51.9 206. ]
#  [ 46.8 189. ]
#  [ 45.7 195. ]
#  [ 55.8 207. ]
#  [ 43.5 202. ]
#  [ 49.6 193. ]
#  [ 50.8 210. ]
#  [ 50.2 198. ]]

# %%
Adelie, Gentoo, Chinstrap = penguin_df[penguin_df['species']=='Adelie'], penguin_df[penguin_df['species']=='Gentoo'], \
penguin_df[penguin_df['species']=='Chinstrap']

plt.scatter(Adelie['culmen_length_mm'], Adelie['flipper_length_mm'], c='blue', s=50,marker='*', label='Adelie', cmap='cividis', edgecolors='k', linewidths=0.5, vmin=170,vmax=230)
plt.scatter(Gentoo['culmen_length_mm'], Gentoo['flipper_length_mm'], c= 'green', s=30,marker='s', label='Gentoo', cmap='cividis', edgecolors='k', linewidths=0.5, vmin=170,vmax=230)
plt.scatter(Chinstrap['culmen_length_mm'], Chinstrap['flipper_length_mm'], c= 'red', s=70,marker='o', label='Chinstrap', cmap='cividis', edgecolors='k', linewidths=0.5, vmin=170,vmax=230)
plt.grid(linestyle='--',alpha=0.3)
plt.ylabel('Culemn Length (mm)')
plt.xlabel('Flipper Length (mm)')
plt.legend()
plt.show()
plt.grid(linestyle='--',alpha=0.3)
plt.ylabel('Culemn Length (mm)')
plt.xlabel('Flipper Length (mm)')
plt.legend()
plt.show()
# Out:
# <ipython-input-40-fc064b1b607e>:4: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap', 'vmin', 'vmax' will be ignored
#   plt.scatter(Adelie['culmen_length_mm'], Adelie['flipper_length_mm'], c='blue', s=50,marker='*', label='Adelie', cmap='cividis', edgecolors='k', linewidths=0.5, vmin=170,vmax=230)
# <ipython-input-40-fc064b1b607e>:5: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap', 'vmin', 'vmax' will be ignored
#   plt.scatter(Gentoo['culmen_length_mm'], Gentoo['flipper_length_mm'], c= 'green', s=30,marker='s', label='Gentoo', cmap='cividis', edgecolors='k', linewidths=0.5, vmin=170,vmax=230)
# <ipython-input-40-fc064b1b607e>:6: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap', 'vmin', 'vmax' will be ignored
#   plt.scatter(Chinstrap['culmen_length_mm'], Chinstrap['flipper_length_mm'], c= 'red', s=70,marker='o', label='Chinstrap', cmap='cividis', edgecolors='k', linewidths=0.5, vmin=170,vmax=230)
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
#@title Skeleton code
plt.scatter(_____, _________,c=_______,s=50,marker=___,label='Adelie', cmap='cividis',edgecolors='k',linewidths=0.5,vmin=___,vmax=___)
plt.scatter(_____, _________,c=_______,s=30,marker=___,label='Gentoo', cmap='cividis',edgecolors='k',linewidths=0.5,vmin=___,vmax=___)
plt.scatter(_____, _________,c=_______,s=70,marker=___,label='Chinstrap', cmap='cividis',edgecolors='k',linewidths=0.5,vmin=____,vmax=____)
plt.______(__________)
plt.ylabel(___________)
plt.xlabel(___________)
plt._________
plt.show()

# %% [markdown]
# ### Q5: Train the KMeans clustering with 2 clusters

# %%
# Train k-means clustering algorithm here

# Predict labels

# %%
# Train k-means clustering algorithm here # Predict labels
Adelie, Gentoo, Chinstrap = penguin_df[penguin_df['species']=='Adelie'], penguin_df[penguin_df['species']=='Gentoo'], \
penguin_df[penguin_df['species']=='Chinstrap']

plt.scatter(Adelie['culmen_length_mm'], Adelie['flipper_length_mm'], c='blue', s=50,marker='*', label='Adelie', cmap='cividis', edgecolors='k', linewidths=0.5, vmin=170,vmax=230)
plt.scatter(Gentoo['culmen_length_mm'], Gentoo['flipper_length_mm'], c= 'green', s=30,marker='s', label='Gentoo', cmap='cividis', edgecolors='k', linewidths=0.5, vmin=170,vmax=230)
plt.scatter(Chinstrap['culmen_length_mm'], Chinstrap['flipper_length_mm'], c= 'red', s=70,marker='o', label='Chinstrap', cmap='cividis', edgecolors='k', linewidths=0.5, vmin=170,vmax=230)
plt.grid(linestyle='--',alpha=0.3)
plt.ylabel('Culemn Length (mm)')
plt.xlabel('Flipper Length (mm)')
plt.legend()
plt.show()
plt.grid(linestyle='--',alpha=0.3)
plt.ylabel('Culemn Length (mm)')
plt.xlabel('Flipper Length (mm)')
plt.legend()
plt.show()

# %%
# Assuming 'penguin_df' is your dataframe with penguin species and measurements

# Separate the data for the two species (Adelie and Gentoo)
Adelie = penguin_df[penguin_df['species'] == 'Adelie']
Gentoo = penguin_df[penguin_df['species'] == 'Gentoo']
Chinstrap = penguin_df[penguin_df['species'] == 'Chinstrap']

# Plotting the scatter plot for Adelie and Gentoo species
plt.scatter(Adelie['culmen_length_mm'], Adelie['flipper_length_mm'],
            c='blue', s=50, marker='*', label='Adelie', edgecolors='k', linewidths=0.5)

plt.scatter(Gentoo['culmen_length_mm'], Gentoo['flipper_length_mm'],
            c='green', s=30, marker='s', label='Gentoo', edgecolors='k', linewidths=0.5)

plt.scatter(Chinstrap['culmen_length_mm'], Chinstrap['flipper_length_mm'],
            c='red', s=70, marker='o', label='Chinstrap', edgecolors='k', linewidths=0.5)
kmeans = KMeans(n_clusters=2, random_state=42)
kmeans.fit(X)

# Step 3: Predict the cluster labels
penguin_df['cluster'] = kmeans.labels_

# Step 4: Plot all species but color them by their predicted clusters
plt.scatter(penguin_df['culmen_length_mm'], penguin_df['flipper_length_mm'],
            c=penguin_df['cluster'], s=50, cmap='coolwarm', edgecolors='k', linewidths=0.5)

# Customizing the plot
plt.grid(linestyle='--', alpha=0.3)
plt.ylabel('Culmen Length (mm)')
plt.xlabel('Flipper Length (mm)')
plt.title('Penguin Data: KMeans Clustering with 2 Clusters')
plt.show()
# Out:
# <ipython-input-47-e4bfc77747d9>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   penguin_df['cluster'] = kmeans.labels_

# %% [markdown]
# We got this figure with our model. Can you recreate it?
#
# ![plot4.png](data:image/png;base64,...)
